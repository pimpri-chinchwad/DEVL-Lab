# %%
import pandas as pd

# %%
import numpy as np

# %%
mySeries=pd.Series([20,35,12,4,84,25,60,67,52,20,90,99,100])

# %%
mySeries.describe()
# Out:
# count     13.000000
# mean      51.384615
# std       34.442073
# min        4.000000
# 25%       20.000000
# 50%       52.000000
# 75%       84.000000
# max      100.000000
# dtype: float64

# %%
mySeries.index=["Tanya", "Sahil", "Rahul", "Akib", "Vishwas", "Shreepad","Atharva", "Soham", "Haha", "Johan", "Mohak", "Dagdu","Vishnu"]

# %%
mySeries
# Out:
# Atharva     90
# Soham       99
# Haha       100
# dtype: int64

# %%
mySeries.title="This is a series data:)"

# %%
mySeries["Soham"]
# Out:
# 99

# %%
mySeries.iloc[0]
# Out:
# 90

# %%
mySeries[-1]
# Out:
# /tmp/ipykernel_7638/2102154360.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mySeries[-1]
# 100

# %%
mySeries["Atharva":"Haha"]
# Out:
# Atharva     90
# Soham       99
# Haha       100
# dtype: int64

# %% [markdown]
# Total marks obtained

# %%
mySeries*5
# Out:
# Atharva    450
# Soham      495
# Haha       500
# dtype: int64

# %%
mySeries>90
# Out:
# Tanya       False
# Sahil       False
# Rahul       False
# Akib        False
# Vishwas     False
# Shreepad    False
# Atharva     False
# Soham       False
# Haha        False
# Johan       False
# Mohak       False
# Dagdu        True
# Vishnu       True
# dtype: bool

# %%
mySeries<=90
# Out:
# Atharva     True
# Soham      False
# Haha       False
# dtype: bool

# %%
mySeries[(mySeries<40)|(mySeries>90)]
# Out:
# Tanya        20
# Sahil        35
# Rahul        12
# Akib          4
# Shreepad     25
# Johan        20
# Dagdu        99
# Vishnu      100
# dtype: int64
