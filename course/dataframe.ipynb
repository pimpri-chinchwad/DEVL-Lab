# %%
import pandas as pd

# %%
df=pd.read_csv("Train.csv")

# %%
df.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %% [markdown]
# Reduce size of dataset

# %%
df=df[0:10]

# %%
df.index=["Atharva", "Soham","Rahul","Mohit", "Vishwesh", "Rahul","Vineet","Ramesh","Mahesh","Shree"]

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Atharva    1               D           Flight                    4
# Soham      2               F           Flight                    4
# Rahul      3               A           Flight                    2
# Mohit      4               B           Flight                    3
# Vishwesh   5               C           Flight                    2
# Rahul      6               F           Flight                    3
# Vineet     7               D           Flight                    3
# Ramesh     8               F           Flight                    4
# Mahesh     9               A           Flight                    3
# Shree     10               B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Atharva                 2                  177                3
# Soham                   5                  216                2
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
df.index
# Out:
# Index(['Atharva', 'Soham', 'Rahul', 'Mohit', 'Vishwesh', 'Rahul', 'Vineet',
#        'Ramesh', 'Mahesh', 'Shree'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Atharva to Shree
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10 non-null     int64
#  1   Warehouse_block      10 non-null     object
#  2   Mode_of_Shipment     10 non-null     object
#  3   Customer_care_calls  10 non-null     int64
#  4   Customer_rating      10 non-null     int64
#  5   Cost_of_the_Product  10 non-null     int64
#  6   Prior_purchases      10 non-null     int64
#  7   Product_importance   10 non-null     object
#  8   Gender               10 non-null     object
#  9   Discount_offered     10 non-null     int64
#  10  Weight_in_gms        10 non-null     int64
#  11  Reached.on.Time_Y.N  10 non-null     int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ KB

# %%
df.size
# Out:
# 120

# %%
df.describe()
# Out:
#              ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10.00000            10.000000        10.000000              10.0000
# mean    5.50000             3.100000         2.600000             189.5000
# std     3.02765             0.737865         1.349897              32.7151
# min     1.00000             2.000000         1.000000             150.0000
# 25%     3.25000             3.000000         2.000000             167.0000
# 50%     5.50000             3.000000         2.000000             180.0000
# 75%     7.75000             3.750000         3.750000             208.0000
# max    10.00000             4.000000         5.000000             250.0000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count        10.000000         10.000000      10.000000                 10.0
# mean          3.000000         31.000000    2099.600000                  1.0
# ...

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Atharva    1               D           Flight                    4
# Soham      2               F           Flight                    4
# Rahul      3               A           Flight                    2
# Mohit      4               B           Flight                    3
# Vishwesh   5               C           Flight                    2
# Rahul      6               F           Flight                    3
# Vineet     7               D           Flight                    3
# Ramesh     8               F           Flight                    4
# Mahesh     9               A           Flight                    3
# Shree     10               B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Atharva                 2                  177                3
# Soham                   5                  216                2
# ...

# %%
df.loc["Atharva"]
# Out:
# ID                          1
# Warehouse_block             D
# Mode_of_Shipment       Flight
# Customer_care_calls         4
# Customer_rating             2
# Cost_of_the_Product       177
# Prior_purchases             3
# Product_importance        low
# Gender                      F
# Discount_offered           44
# Weight_in_gms            1233
# Reached.on.Time_Y.N         1
# Name: Atharva, dtype: object

# %%
df.iloc[0]
# Out:
# ID                          1
# Warehouse_block             D
# Mode_of_Shipment       Flight
# Customer_care_calls         4
# Customer_rating             2
# Cost_of_the_Product       177
# Prior_purchases             3
# Product_importance        low
# Gender                      F
# Discount_offered           44
# Weight_in_gms            1233
# Reached.on.Time_Y.N         1
# Name: Atharva, dtype: object

# %%
df.iloc[0].name="Riya"

# %%
df.loc["Atharva":"Mahesh", ["Gender", "Mode_of_Shipment"]]
# Out:
#          Gender Mode_of_Shipment
# Atharva       F           Flight
# Soham         M           Flight
# Rahul         M           Flight
# Mohit         M           Flight
# Vishwesh      F           Flight
# Rahul         F           Flight
# Vineet        F           Flight
# Ramesh        F           Flight
# Mahesh        F           Flight

# %%
df.iloc[0:5, [3]]
# Out:
#           Customer_care_calls
# Atharva                     4
# Soham                       4
# Rahul                       2
# Mohit                       3
# Vishwesh                    2

# %%
df.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
df[df["Prior_purchases"]==3]
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Atharva    1               D           Flight                    4
# Vishwesh   5               C           Flight                    2
# Rahul      6               F           Flight                    3
# Vineet     7               D           Flight                    3
# Mahesh     9               A           Flight                    3
# Shree     10               B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Atharva                 2                  177                3
# Vishwesh                2                  184                3
# Rahul                   1                  162                3
# Vineet                  4                  250                3
# Mahesh                  4                  150                3
# Shree                   2                  164                3
#
# ...

# %% [markdown]
# Dropping stuff

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Soham      2               F           Flight                    4
# Rahul      3               A           Flight                    2
# Mohit      4               B           Flight                    3
# Vishwesh   5               C           Flight                    2
# Rahul      6               F           Flight                    3
# Vineet     7               D           Flight                    3
# Ramesh     8               F           Flight                    4
# Mahesh     9               A           Flight                    3
# Shree     10               B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Soham                   5                  216                2
# Rahul                   2                  183                4
# Mohit                   3                  176                4
# ...

# %%
df
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Atharva    1               D           Flight                    4
# Soham      2               F           Flight                    4
# Rahul      3               A           Flight                    2
# Mohit      4               B           Flight                    3
# Vishwesh   5               C           Flight                    2
# Rahul      6               F           Flight                    3
# Vineet     7               D           Flight                    3
# Ramesh     8               F           Flight                    4
# Mahesh     9               A           Flight                    3
# Shree     10               B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Atharva                 2                  177                3
# Soham                   5                  216                2
# ...

# %%
#dropping rows
df.drop("Atharva", axis=0)
#Note: df is not changed.
#To change df, run df=df.drop("Atharva")
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Soham      2               F           Flight                    4
# Rahul      3               A           Flight                    2
# Mohit      4               B           Flight                    3
# Vishwesh   5               C           Flight                    2
# Rahul      6               F           Flight                    3
# Vineet     7               D           Flight                    3
# Ramesh     8               F           Flight                    4
# Mahesh     9               A           Flight                    3
# Shree     10               B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Soham                   5                  216                2
# Rahul                   2                  183                4
# Mohit                   3                  176                4
# ...

# %%
#dropping columns
df.drop("ID", axis=1)
# Out:
#          Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# Atharva                D           Flight                    4
# Soham                  F           Flight                    4
# Rahul                  A           Flight                    2
# Mohit                  B           Flight                    3
# Vishwesh               C           Flight                    2
# Rahul                  F           Flight                    3
# Vineet                 D           Flight                    3
# Ramesh                 F           Flight                    4
# Mahesh                 A           Flight                    3
# Shree                  B           Flight                    3
#
#           Customer_rating  Cost_of_the_Product  Prior_purchases  \
# Atharva                 2                  177                3
# Soham                   5                  216                2
# Rahul                   2                  183                4
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %%
df.drop(['ID', 'Warehouse_block','Mode_of_Shipment','Gender'], axis=1)
# Out:
#           Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# Atharva                     4                2                  177
# Soham                       4                5                  216
# Rahul                       2                2                  183
# Mohit                       3                3                  176
# Vishwesh                    2                2                  184
# Rahul                       3                1                  162
# Vineet                      3                4                  250
# Ramesh                      4                1                  233
# Mahesh                      3                4                  150
# Shree                       3                2                  164
#
#           Prior_purchases Product_importance  Discount_offered  Weight_in_gms  \
# Atharva                 3                low                44           1233
# ...

# %%
df['Gender'] = df['Gender'].map({'F': 0, 'M': 1})

# %%
df["Gender"]
# Out:
# Atharva    NaN
# Soham      NaN
# Rahul      NaN
# Mohit      NaN
# Vishwesh   NaN
# Rahul      NaN
# Vineet     NaN
# Ramesh     NaN
# Mahesh     NaN
# Shree      NaN
# Name: Gender, dtype: float64
