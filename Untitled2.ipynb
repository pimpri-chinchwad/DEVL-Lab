# %%
import matplotlib.pyplot as plt

x=[10,20,30,40,50,60]
y=[1,3,5,6,8,9]

plt.plot(x,y)

plt.show()

# %%
x=[10,20,5,96,12,4]
y=["Mon", "Tue", "Wed", "Thur", "Fri", "Sat"]

plt.bar(y,x)

plt.show()

# %%
x=[4,25,10,1,2,5,8,9,5,2,3,5,2,4,1,1,0,1,4,5,25,2,1,14,45,2,1,2]

plt.hist(x, bins=50)

plt.show()
